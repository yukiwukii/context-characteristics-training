# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /home/users/ntu/clar0092/.conda/envs/acupred/lib/python3.11/site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in /home/users/ntu/clar0092/.conda/envs/acupred/lib/python3.11/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.8.0 in /home/users/ntu/clar0092/.conda/envs/acupred/lib/python3.11/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/users/ntu/clar0092/.conda/envs/acupred/lib/python3.11/site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/users/ntu/clar0092/.conda/envs/acupred/lib/python3.11/site-packages (from scikit-learn) (3.6.0)

# %%
import torch

print(torch.cuda.is_available())
# Out:
# True

# %%
import pandas as pd
from bertopic import BERTopic

data = pd.read_csv("data/ethiX.csv")
data = data[data['Debate'] == "Should euthanasia be legalized?"]
data = data['Argument']

topic_model = BERTopic(language="english", calculate_probabilities=True, verbose=True)
topics, probs = topic_model.fit_transform(data)
# Out:
# 2025-10-04 16:19:39,548 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# 2025-10-04 16:19:46,433 - BERTopic - Embedding - Completed ✓
# 2025-10-04 16:19:46,434 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-10-04 16:19:46,493 - BERTopic - Dimensionality - Completed ✓
# 2025-10-04 16:19:46,494 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-10-04 16:19:46,497 - BERTopic - Cluster - Completed ✓
# 2025-10-04 16:19:46,499 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2025-10-04 16:19:46,503 - BERTopic - Representation - Completed ✓

# %%
topic_model.visualize_barchart(top_n_topics=22)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 topic_model.visualize_barchart(top_n_topics=22)
#
# File ~/.conda/envs/acupred/lib/python3.11/site-packages/bertopic/_bertopic.py:3262, in BERTopic.visualize_barchart(self, topics, top_n_topics, n_words, custom_labels, title, width, height, autoscale)
#    3230 """Visualize a barchart of selected topics.
#    3231
#    3232 Arguments:
#    (...)   3259 ```
#    3260 """
#    3261 check_is_fitted(self)
# -> 3262 return plotting.visualize_barchart(
#    3263     self,
#    3264     topics=topics,
#    3265     top_n_topics=top_n_topics,
#    3266     n_words=n_words,
#    3267     custom_labels=custom_labels,
#    3268     title=title,
#    3269     width=width,
#    3270     height=height,
#    3271     autoscale=autoscale,
#    3272 )
#
# File ~/.conda/envs/acupred/lib/python3.11/site-packages/bertopic/plotting/_barchart.py:78, in visualize_barchart(topic_model, topics, top_n_topics, n_words, custom_labels, title, width, height, autoscale)
#      76 columns = 4
#      77 rows = int(np.ceil(len(topics) / columns))
# ---> 78 fig = make_subplots(
#      79     rows=rows,
#      80     cols=columns,
#      81     shared_xaxes=False,
#      82     horizontal_spacing=0.1,
#      83     vertical_spacing=0.4 / rows if rows > 1 else 0,
#      84     subplot_titles=subplot_titles,
#      85 )
#      87 # Add barchart for each topic
#      88 row = 1
#
# File ~/.conda/envs/acupred/lib/python3.11/site-packages/plotly/subplots.py:305, in make_subplots(rows, cols, shared_xaxes, shared_yaxes, start_cell, print_grid, horizontal_spacing, vertical_spacing, subplot_titles, column_widths, row_heights, specs, insets, column_titles, row_titles, x_title, y_title, figure, **kwargs)
#       6 def make_subplots(
#       7     rows=1,
#       8     cols=1,
#    (...)     25     **kwargs,
#      26 ) -> go.Figure:
#      27     """
#      28     Return an instance of plotly.graph_objs.Figure with predefined subplots
#      29     configured in 'layout'.
#    (...)    302     Figure(...)
#     303     """
# --> 305     return _sub.make_subplots(
#     306         rows,
#     307         cols,
#     308         shared_xaxes,
#     309         shared_yaxes,
#     310         start_cell,
#     311         print_grid,
#     312         horizontal_spacing,
#     313         vertical_spacing,
#     314         subplot_titles,
#     315         column_widths,
#     316         row_heights,
#     317         specs,
#     318         insets,
#     319         column_titles,
#     320         row_titles,
#     321         x_title,
#     322         y_title,
#     323         figure,
#     324         **kwargs,
#     325     )
#
# File ~/.conda/envs/acupred/lib/python3.11/site-packages/plotly/_subplots.py:360, in make_subplots(rows, cols, shared_xaxes, shared_yaxes, start_cell, print_grid, horizontal_spacing, vertical_spacing, subplot_titles, column_widths, row_heights, specs, insets, column_titles, row_titles, x_title, y_title, figure, **kwargs)
#     356     # Validate coerce inputs
#     357     # ----------------------
#     358     #  ### rows ###
#     359     if not isinstance(rows, int) or rows <= 0:
# --> 360         raise ValueError(
#     361             """
#     362 The 'rows' argument to make_subplots must be an int greater than 0.
#     363     Received value of type {typ}: {val}""".format(typ=type(rows), val=repr(rows))
#     364         )
#     366     #  ### cols ###
#     367     if not isinstance(cols, int) or cols <= 0:
#
# ValueError:
# The 'rows' argument to make_subplots must be an int greater than 0.
#     Received value of type <class 'int'>: 0

# %%
freq = topic_model.get_topic_info(); freq.head(5)
# Out:
#    Topic  Count                     Name  \
# 0     -1     35  -1_to_euthanasia_the_is
#
#                                       Representation  \
# 0  [to, euthanasia, the, is, of, be, and, for, it...
#
#                                  Representative_Docs
# 0  [The cost of palliative care is extremely high...
